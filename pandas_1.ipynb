# %% [markdown]
# <a href="https://colab.research.google.com/github/NAMITHASS/SCRATCH/blob/main/pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
a=np.array([11,12,13,14,8])
print(type(a))
print(a[1])
# Out:
# <class 'numpy.ndarray'>
# 12

# %%
s=pd.Series([10,12,13,14,15])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    10
# 1    12
# 2    13
# 3    14
# 4    15
# dtype: int64

# %%
s[3]
# Out:
# 14

# %%
s.drop(2)
# Out:
# 0    10
# 1    12
# 3    14
# 4    15
# dtype: int64

# %%
s.drop(2,inplace=True)

# %%
s.iloc[0]
# Out:
# 10

# %%
s.loc[1]
# Out:
# 12

# %%
ss=pd.Series([10,12,13,14,15],index=['a','b','a','d','e'])
ss
# Out:
# a    10
# b    12
# a    13
# d    14
# e    15
# dtype: int64

# %%
ss.loc['a']
# Out:
# a    10
# a    13
# dtype: int64

# %%
ss.iloc[1]
# Out:
# 12

# %%
data=[['amul',10,'1-1-22'],['nami',12,None],['abi',None,'3-3-24'],['kavi',22,'4-4-21']]
data
# Out:
# [['amul', 10, '1-1-22'],
#  ['nami', 12, None],
#  ['abi', None, '3-3-24'],
#  ['kavi', 22, '4-4-21']]

# %%
df=pd.DataFrame(data) #pd.DataFrame([data]for single line)
df
# Out:
#       0     1       2
# 0  amul  10.0  1-1-22
# 1  nami  12.0    None
# 2   abi   NaN  3-3-24
# 3  kavi  22.0  4-4-21

# %%
df[0:2]
# Out:
#       0     1       2
# 0  amul  10.0  1-1-22
# 1  nami  12.0    None

# %%
df[[0,2]]
# Out:
#       0       2
# 0  amul  1-1-22
# 1  nami    None
# 2   abi  3-3-24
# 3  kavi  4-4-21

# %%
df[0]
# Out:
# 0    amul
# 1    nami
# 2     abi
# 3    kavi
# Name: 0, dtype: object

# %%
df[0][1]
# Out:
# 'nami'

# %%
df[1:2]
# Out:
#       0     1     2
# 1  nami  12.0  None

# %%
df=pd.DataFrame(data,columns=['firstname','age','dob'])
df
# Out:
#   firstname   age     dob
# 0      amul  10.0  1-1-22
# 1      nami  12.0    None
# 2       abi   NaN  3-3-24
# 3      kavi  22.0  4-4-21

# %%
df['firstname']
# Out:
# 0    amul
# 1    nami
# 2     abi
# 3    kavi
# Name: firstname, dtype: object

# %%
df.loc[0,'firstname']
# Out:
# 'amul'

# %%
df.iloc[:1]
# Out:
#   firstname   age     dob
# 0      amul  10.0  1-1-22

# %%
df['firstname'][0]
# Out:
# 'amul'

# %%
df.loc[0,'age']
# Out:
# 10.0

# %%
df[0:1]
# Out:
#   firstname   age     dob
# 0      amul  10.0  1-1-22

# %%
s=pd.Series([1,2,3])
s
s.plot()
# Out:
# <Axes: >

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s=s.to_numpy()
s
# Out:
# array([1, 2, 3])

# %%
type(s)
# Out:
# numpy.ndarray

# %%
df.head()
# Out:
#   firstname   age     dob
# 0      amul  10.0  1-1-22
# 1      nami  12.0    None
# 2       abi   NaN  3-3-24
# 3      kavi  22.0  4-4-21

# %%
df.head(1)
# Out:
#   firstname   age     dob
# 0      amul  10.0  1-1-22

# %%
df.tail(-3)
# Out:
#   firstname   age     dob
# 3      kavi  22.0  4-4-21

# %%
# None,' ','-','?','Nil',np.nan(not a number)

# %%
df
# Out:
#   firstname   age     dob
# 0      amul  10.0  1-1-22
# 1      nami  12.0    None
# 2       abi   NaN  3-3-24
# 3      kavi  22.0  4-4-21

# %%
df.isnull()
# Out:
#    firstname    age    dob
# 0      False  False  False
# 1      False  False   True
# 2      False   True  False
# 3      False  False  False

# %%
df.isnull().sum()
# Out:
# firstname    0
# age          1
# dob          1
# dtype: int64

# %%
s1=[['amul',10,'1-1-22'],['nami',12,None],['abi',None,'3-3-24'],['kavi',None,'4-4-21'],['deep',None,'5-4-2021']]
s1
# Out:
# [['amul', 10, '1-1-22'],
#  ['nami', 12, None],
#  ['abi', None, '3-3-24'],
#  ['kavi', None, '4-4-21'],
#  ['deep', None, '5-4-2021']]

# %%
d1=pd.DataFrame(s1)
d1
# Out:
#       0     1         2
# 0  amul  10.0    1-1-22
# 1  nami  12.0      None
# 2   abi   NaN    3-3-24
# 3  kavi   NaN    4-4-21
# 4  deep   NaN  5-4-2021

# %%
df.drop(['age'], axis=1, inplace=True)

# %%
d1.isnull().sum()
# Out:
# 0    0
# 1    3
# 2    1
# dtype: int64

# %%
d1.dropna()#remove of drop
# Out:
#       0     1       2
# 0  amul  10.0  1-1-22

# %%
d1.dropna()
# Out:
#       0     1       2
# 0  amul  10.0  1-1-22

# %%
d1.drop([0,2])
# Out:
#       0     1         2
# 1  nami  12.0      None
# 3  kavi   NaN    4-4-21
# 4  deep   NaN  5-4-2021

# %%
a
# Out:
# array([11, 12, 13, 14,  8])

# %%
a>12
# Out:
# array([False, False,  True,  True, False])

# %%
a[a>12]
# Out:
# array([13, 14])

# %%
a[a%2!=0]
# Out:
# array([11, 13])

# %%
df
# Out:
#   firstname     dob
# 0      amul  1-1-22
# 1      nami    None
# 2       abi  3-3-24
# 3      kavi  4-4-21

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   firstname  4 non-null      object
#  1   dob        3 non-null      object
# dtypes: object(2)
# memory usage: 192.0+ bytes

# %%
df['firstname'].str.contains('e')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# Name: firstname, dtype: bool

# %%
df['firstname'].str.contains('i')
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: firstname, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.columns)
print(df.values)
# Out:
# (4, 2)
# 8
# [RangeIndex(start=0, stop=4, step=1), Index(['firstname', 'dob'], dtype='object')]
# 2
# firstname    object
# dob          object
# dtype: object
# Index(['firstname', 'dob'], dtype='object')
# [['amul' '1-1-22']
#  ['nami' None]
#  ['abi' '3-3-24']
#  ['kavi' '4-4-21']]

# %%
df.tail()
# Out:
#   firstname     dob
# 0      amul  1-1-22
# 1      nami    None
# 2       abi  3-3-24
# 3      kavi  4-4-21

# %%
df.head()
# Out:
#   firstname     dob
# 0      amul  1-1-22
# 1      nami    None
# 2       abi  3-3-24
# 3      kavi  4-4-21

# %%
df2=pd.concat([df,df])
df2
# Out:
#   firstname     dob
# 0      amul  1-1-22
# 1      nami    None
# 2       abi  3-3-24
# 3      kavi  4-4-21
# 0      amul  1-1-22
# 1      nami    None
# 2       abi  3-3-24
# 3      kavi  4-4-21

# %%
df.describe()
# Out:
#        firstname     dob
# count          4       3
# unique         4       3
# top         amul  1-1-22
# freq           1       1

# %%
df['firstname']
# Out:
# 0    amul
# 1    nami
# 2     abi
# 3    kavi
# Name: firstname, dtype: object

# %%
df.dob
# Out:
# 0    1-1-22
# 1      None
# 2    3-3-24
# 3    4-4-21
# Name: dob, dtype: object

# %%
df[['firstname','dob']]
# Out:
#   firstname     dob
# 0      amul  1-1-22
# 1      nami    None
# 2       abi  3-3-24
# 3      kavi  4-4-21

# %%
df.loc[0][0]
# Out:
# 'amul'

# %%
df.loc[0,'firstname']
# Out:
# 'amul'

# %%
df.iloc[0,1]
# Out:
# '1-1-22'

# %%
df.iloc[0][0]
# Out:
# 'amul'

# %%
df['dob'][1]='18-12-22'

# %%
df
# Out:
#   firstname       dob
# 0      amul    1-1-22
# 1      nami  18-12-22
# 2       abi    3-3-24
# 3      kavi    4-4-21

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/Suriya")
df
# Out:
# [           Suriya                                           Suriya.1
#  0  Suriya in 2011                                     Suriya in 2011
#  1            Born  Saravanan Sivakumar  (age 48)[1][2] Madras (no...
#  2      Alma mater                            Loyola College, Chennai
#  3     Occupations  .mw-parser-output .hlist dl,.mw-parser-output ...
#  4    Years active                                       1997–present
#  5          Spouse  .mw-parser-output .marriage-line-margin2px{lin...
#  6        Children                                                  2
#  7          Parent                                          Sivakumar
#  8       Relatives                  Karthi (brother) Brindha (sister)
#  9          Awards                                         See awards,
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteNational Film Award for Best Actor  \
#  0                                          1967–1980
#  1                                          1981–2000
#  2                                       2001–present
#
#    .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteNational Film Award for Best Actor.1
#  0  Uttam Kumar (1967) Ashok Kumar (1968) Utpal Du...
#  1  Om Puri (1981) Kamal Haasan (1982) Om Puri (19...
#  2  Murali (2001) Ajay Devgn (2002) Vikram (2003) ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ,
#    vteFilmfare Award for Best Tamil Actor  \
#  0                              1972–1989
#  1                              1990–2009
#  2                              2010–2019
#
#              vteFilmfare Award for Best Tamil Actor.1
#  0  Sivaji Ganesan (1972) Sivaji Ganesan (1973) Ge...
#  1  Karthik (1990) Kamal Haasan (1991) Kamal Haasa...
#  2  Vikram (2010) Dhanush (2011) Dhanush (2012) At...  ,
#    vteTamil Nadu State Film Award for Best Actor  \
#  0                                     1967–1980
#  1                                     1981–2000
#  2                                  2001–present
#
#       vteTamil Nadu State Film Award for Best Actor.1
#  0  A. V. M. Rajan (1967) M. G. Ramachandran (1968...
#  1  Kamal Haasan (1981) Sivakumar (1982) no award ...
#  2  Suriya (2001) Madhavan (2002) Vikram (2003) Ja...  ,
#    vte2D Entertainment                              vte2D Entertainment.1
#  0          Key people                   Suriya Rajsekar Pandian Jyothika
#  1      Films produced  36 Vayadhinile (2015) Pasanga 2 (2015) 24 (201...
#  2   Films distributed  Singam II (2013) Kadugu (2017) Sillu Karuppatt...,
#    Authority control databases          Authority control databases.1
#  0               International                         FAST ISNI VIAF
#  1                    National  France BnF data Germany United States
#  2                     Artists                            MusicBrainz]

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.head(10)

# %%
type(df.item_name)
# Out:
# pandas.core.series.Series

# %%
type(df.item_price[0])
# Out:
# str

# %%
df.item_price=df.item_price.str.replace('$','')
# Out:
# <ipython-input-163-20961e8be3c3>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.item_price=df.item_price.astype(float)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 3                                                   NaN        2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# ...                                                 ...         ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...       11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...        8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...        8.75
#
# [4622 rows x 5 columns]

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
#df.item_price*100

# %%
df.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
#        'Burrito', 'Crispy Tacos', 'Carnitas Crispy Tacos', 'Steak Salad',
#        'Chips and Mild Fresh Tomato Salsa', 'Veggie Soft Tacos',
#        'Carnitas Salad Bowl', 'Barbacoa Salad Bowl', 'Salad',
#        'Veggie Crispy Tacos', 'Veggie Salad', 'Carnitas Salad'],
#       dtype=object)

# %%
df_drink=df[df.item_price<1.1]
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# 4590  [Roasted Chili Corn Salsa, [Rice, Black Beans,...       11.25
# 4591  [Tomatillo Red Chili Salsa, [Rice, Black Beans...        8.75
# 4595  [Tomatillo Green Chili Salsa, [Rice, Black Bea...        8.75
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]        8.75
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
#
# [726 rows x 5 columns]

# %%
df[df.item_name=='Steak Burrito']
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description  item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...        8.99
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...       11.75
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...        8.99
# ...                                                 ...         ...
# 4546  [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]        9.25
# 4607  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...       11.75
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...       11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...       11.75
#
# [368 rows x 5 columns]

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# [Roasted Chili Corn Salsa, [Fajita Vegetables, Black Beans, Sour Cream, Lettuce, Guacamole]]                                 1
# [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                       1
# [Fresh Tomato Salsa, [Sour Cream, Guacamole, Rice, Lettuce]]                                                                 1
# [Fresh Tomato Salsa (Mild), [Rice, Fajita Veggies, Cheese, Lettuce]]                                                         1
# Name: choice_description, Length: 251, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df[df.item_name=='Chicken Bowl'].choice_description.nunique()
# Out:
# 348

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price<10)&(df.item_name=='Chicken Bowl')].sort_values(['item_price'])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# 1876  [Tomatillo Green Chili Salsa, [Rice, Black Bea...        8.75
# 1852    [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]        8.75
# 1851  [Roasted Chili Corn Salsa, [Rice, Cheese, Sour...        8.75
# 1829    [Fresh Tomato Salsa, [Fajita Vegetables, Rice]]        8.75
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
#
# [422 rows x 5 columns]

# %%
movies=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
movies.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# 0      Crime       142  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      Crime       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2      Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3     Action       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4      Crime       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5      Drama        96  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6    Western       161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...
# 7  Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 8  Biography       195  [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 9      Drama       139  [u'Brad Pitt', u'Edward Norton', u'Helena Bonh...

# %%
movies[(movies.star_rating>=8)&(movies.genre=="Action")].sort_values(['duration'])
# Out:
#      star_rating                                           title  \
# 276          8.1                            A Fistful of Dollars
# 327          8.0                    The Adventures of Robin Hood
# 235          8.1                                         Yip Man
# 281          8.1                                  The Terminator
# 123          8.3                                     The General
# 96           8.4                                         Yojimbo
# 198          8.1                               Kill Bill: Vol. 1
# 349          8.0                                      District 9
# 391          8.0                                Edge of Tomorrow
# 239          8.1                   Elite Squad: The Enemy Within
# 37           8.6                         Raiders of the Lost Ark
# 261          8.1                                     Elite Squad
# 240          8.1                            The Bourne Ultimatum
# 366          8.0                                        Serenity
# 196          8.1                         Guardians of the Galaxy
# 19           8.7                                       Star Wars
# 163          8.2                                            Rush
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 100          8.3                The Treasure of the Sierra Madre
# 312          8.0                                       Star Trek
# 118          8.3              Indiana Jones and the Last Crusade
# 194          8.1                    Kingsman: The Secret Service
# 248          8.1                      X-Men: Days of Future Past
# 138          8.3                                        Die Hard
# 152          8.2                                  V for Vendetta
# 388          8.0                              The Blues Brothers
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 20           8.7                                      The Matrix
# 75           8.4                                          Aliens
# 45           8.5                      Terminator 2: Judgment Day
# 354          8.0                               Kill Bill: Vol. 2
# 301          8.0                                       Furious 7
# 173          8.2              Tae Guk Gi: The Brotherhood of War
# 113          8.3                                   Batman Begins
# 177          8.2                                    The Avengers
# 380          8.0                                   Casino Royale
# 296          8.1                                  The Wild Bunch
# 11           8.8                                       Inception
# 268          8.1                                      The Raid 2
# 3            9.0                                 The Dark Knight
# 44           8.5                                       Gladiator
# 129          8.3                                             Ran
# 43           8.5                           The Dark Knight Rises
# 36           8.6                             Saving Private Ryan
# 135          8.3                                            Heat
# 82           8.4                                      Braveheart
# 385          8.0                                       Spartacus
#
#     content_rating   genre  duration  \
# 276              R  Action        99
# 327             PG  Action       102
# 235              R  Action       106
# 281              R  Action       107
# 123        UNRATED  Action       107
# 96         UNRATED  Action       110
# 198              R  Action       111
# 349              R  Action       112
# 391          PG-13  Action       113
# 239        UNRATED  Action       115
# 37              PG  Action       115
# 261              R  Action       115
# 240          PG-13  Action       115
# 366          PG-13  Action       119
# 196          PG-13  Action       121
# 19              PG  Action       121
# 163              R  Action       123
# 12              PG  Action       124
# 100      NOT RATED  Action       126
# 312          PG-13  Action       127
# 118          PG-13  Action       127
# 194              R  Action       129
# 248          PG-13  Action       131
# 138              R  Action       131
# 152              R  Action       132
# 388              R  Action       133
# 80              PG  Action       134
# 20               R  Action       136
# 75               R  Action       137
# 45               R  Action       137
# 354              R  Action       137
# 301          PG-13  Action       137
# 173              R  Action       140
# 113          PG-13  Action       140
# 177          PG-13  Action       143
# 380          PG-13  Action       144
# 296              R  Action       145
# 11           PG-13  Action       148
# 268              R  Action       150
# 3            PG-13  Action       152
# 44               R  Action       155
# 129              R  Action       162
# 43           PG-13  Action       165
# 36               R  Action       169
# 135              R  Action       170
# 82               R  Action       177
# 385          PG-13  Action       197
#
#                                            actors_list
# 276  [u'Clint Eastwood', u'Gian Maria Volont\xe9', ...
# 327  [u'Errol Flynn', u'Olivia de Havilland', u'Bas...
# 235     [u'Donnie Yen', u'Simon Yam', u'Siu-Wong Fan']
# 281  [u'Arnold Schwarzenegger', u'Linda Hamilton', ...
# 123  [u'Buster Keaton', u'Marion Mack', u'Glen Cave...
# 96   [u'Toshir\xf4 Mifune', u'Eijir\xf4 T\xf4no', u...
# 198  [u'Uma Thurman', u'David Carradine', u'Daryl H...
# 349  [u'Sharlto Copley', u'David James', u'Jason Co...
# 391    [u'Tom Cruise', u'Emily Blunt', u'Bill Paxton']
# 239  [u'Wagner Moura', u'Irandhir Santos', u'Andr\x...
# 37   [u'Harrison Ford', u'Karen Allen', u'Paul Free...
# 261  [u'Wagner Moura', u'Andr\xe9 Ramiro', u'Caio J...
# 240  [u'Matt Damon', u'\xc9dgar Ram\xedrez', u'Joan...
# 366  [u'Nathan Fillion', u'Gina Torres', u'Chiwetel...
# 196  [u'Chris Pratt', u'Vin Diesel', u'Bradley Coop...
# 19   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 163  [u'Daniel Br\xfchl', u'Chris Hemsworth', u'Oli...
# 12   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 100  [u'Humphrey Bogart', u'Walter Huston', u'Tim H...
# 312  [u'Chris Pine', u'Zachary Quinto', u'Simon Pegg']
# 118  [u'Harrison Ford', u'Sean Connery', u'Alison D...
# 194  [u'Colin Firth', u'Taron Egerton', u'Samuel L....
# 248  [u'Patrick Stewart', u'Ian McKellen', u'Hugh J...
# 138  [u'Bruce Willis', u'Alan Rickman', u'Bonnie Be...
# 152  [u'Hugo Weaving', u'Natalie Portman', u'Rupert...
# 388  [u'John Belushi', u'Dan Aykroyd', u'Cab Callow...
# 80   [u'Mark Hamill', u'Harrison Ford', u'Carrie Fi...
# 20   [u'Keanu Reeves', u'Laurence Fishburne', u'Car...
# 75   [u'Sigourney Weaver', u'Michael Biehn', u'Carr...
# 45   [u'Arnold Schwarzenegger', u'Linda Hamilton', ...
# 354  [u'Uma Thurman', u'David Carradine', u'Michael...
# 301  [u'Vin Diesel', u'Paul Walker', u'Dwayne Johns...
# 173      [u'Dong-gun Jang', u'Bin Won', u'Eun-ju Lee']
# 113  [u'Christian Bale', u'Michael Caine', u'Ken Wa...
# 177  [u'Robert Downey Jr.', u'Chris Evans', u'Scarl...
# 380     [u'Daniel Craig', u'Eva Green', u'Judi Dench']
# 296  [u'William Holden', u'Ernest Borgnine', u'Robe...
# 11   [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 268   [u'Iko Uwais', u'Yayan Ruhian', u'Arifin Putra']
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 44   [u'Russell Crowe', u'Joaquin Phoenix', u'Conni...
# 129  [u'Tatsuya Nakadai', u'Akira Terao', u'Jinpach...
# 43   [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...
# 36      [u'Tom Hanks', u'Matt Damon', u'Tom Sizemore']
# 135   [u'Al Pacino', u'Robert De Niro', u'Val Kilmer']
# 82   [u'Mel Gibson', u'Sophie Marceau', u'Patrick M...
# 385  [u'Kirk Douglas', u'Laurence Olivier', u'Jean ...

# %%
movies[movies.actors_list.str.contains('Leonardo DiCaprio')].sort_values(['star_rating']and['duration'])
# Out:
#      star_rating                        title content_rating      genre  \
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
# 143          8.2      The Wolf of Wall Street              R  Biography
# 620          7.7                      Titanic          PG-13      Drama
#
#      duration                                        actors_list
# 562       118  [u'Johnny Depp', u'Leonardo DiCaprio', u'Julie...
# 244       138  [u'Leonardo DiCaprio', u'Emily Mortimer', u'Ma...
# 340       141  [u'Leonardo DiCaprio', u'Tom Hanks', u'Christo...
# 309       143  [u'Leonardo DiCaprio', u'Djimon Hounsou', u'Je...
# 11        148  [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 49        151  [u'Leonardo DiCaprio', u'Matt Damon', u'Jack N...
# 59        165  [u'Jamie Foxx', u'Christoph Waltz', u'Leonardo...
# 828       167  [u'Leonardo DiCaprio', u'Cameron Diaz', u'Dani...
# 888       170  [u'Leonardo DiCaprio', u'Cate Blanchett', u'Ka...
# 143       180  [u'Leonardo DiCaprio', u'Jonah Hill', u'Margot...
# 620       194  [u'Leonardo DiCaprio', u'Kate Winslet', u'Bill...

# %%
movies[movies.actors_list.str.contains('Leonardo DiCaprio')].sort_values(['star_rating','duration'],ascending=(False,True))
# Out:
#      star_rating                        title content_rating      genre  \
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 143          8.2      The Wolf of Wall Street              R  Biography
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 620          7.7                      Titanic          PG-13      Drama
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
#
#      duration                                        actors_list
# 11        148  [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# 49        151  [u'Leonardo DiCaprio', u'Matt Damon', u'Jack N...
# 59        165  [u'Jamie Foxx', u'Christoph Waltz', u'Leonardo...
# 143       180  [u'Leonardo DiCaprio', u'Jonah Hill', u'Margot...
# 244       138  [u'Leonardo DiCaprio', u'Emily Mortimer', u'Ma...
# 340       141  [u'Leonardo DiCaprio', u'Tom Hanks', u'Christo...
# 309       143  [u'Leonardo DiCaprio', u'Djimon Hounsou', u'Je...
# 562       118  [u'Johnny Depp', u'Leonardo DiCaprio', u'Julie...
# 620       194  [u'Leonardo DiCaprio', u'Kate Winslet', u'Bill...
# 828       167  [u'Leonardo DiCaprio', u'Cameron Diaz', u'Dani...
# 888       170  [u'Leonardo DiCaprio', u'Cate Blanchett', u'Ka...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo.head(10)
# Out:
#                    City Colors Reported Shape Reported State              Time
# 0                Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ   6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS    6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY   4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND   9/15/1934 15:30
# 6           Crater Lake             NaN         CIRCLE    CA    6/15/1935 0:00
# 7                  Alma             NaN           DISK    MI    7/15/1936 0:00
# 8               Eklutna             NaN          CIGAR    AK  10/15/1936 17:00
# 9               Hubbard             NaN       CYLINDER    OR    6/15/1937 0:00

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
drinks=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.beer_servings.min()
# Out:
# 0

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks[drinks.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
